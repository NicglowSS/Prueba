# %%
# %pip install comet_ml #libreria a instalar
# Out:
# Requirement already satisfied: comet_ml in /usr/local/lib/python3.10/dist-packages (3.35.3)
# Requirement already satisfied: jsonschema!=3.1.0,>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (4.19.2)
# Requirement already satisfied: psutil>=5.6.3 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (5.9.5)
# Requirement already satisfied: python-box<7.0.0 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (6.1.0)
# Requirement already satisfied: requests-toolbelt>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (1.0.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (2.31.0)
# Requirement already satisfied: semantic-version>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (2.10.0)
# Requirement already satisfied: sentry-sdk>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (1.38.0)
# Requirement already satisfied: simplejson in /usr/local/lib/python3.10/dist-packages (from comet_ml) (3.19.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from comet_ml) (1.16.0)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (2.0.7)
# Requirement already satisfied: websocket-client<1.4.0,>=0.55.0 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (1.3.3)
# Requirement already satisfied: wrapt>=1.11.2 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (1.14.1)
# Requirement already satisfied: wurlitzer>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (3.0.3)
# Requirement already satisfied: everett[ini]<3.2.0,>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (3.1.0)
# Requirement already satisfied: dulwich!=0.20.33,>=0.20.6 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (0.21.6)
# Requirement already satisfied: rich>=13.3.2 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (13.7.0)
# Requirement already satisfied: configobj in /usr/local/lib/python3.10/dist-packages (from everett[ini]<3.2.0,>=1.0.1->comet_ml) (5.0.8)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (2023.11.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (0.31.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (0.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->comet_ml) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->comet_ml) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->comet_ml) (2023.7.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=13.3.2->comet_ml) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=13.3.2->comet_ml) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=13.3.2->comet_ml) (0.1.2)

# %%
import comet_ml
comet_ml.init(project_name="RNA_Densa_L2") #nombre a dar al experimento
# Out:
# Please paste your Comet API key from https://www.comet.com/api/my/settings/
# (api key may not show as you type)
# Comet API key: ··········
# COMET INFO: Valid Comet API Key saved in /root/.comet.config (set COMET_CONFIG to change where it is saved).

# %%
# Imports
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.datasets import mnist #base de datos
from tensorflow.keras.models import Sequential # checar cada uno de los que faltan
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Input
from tensorflow.keras.optimizers import RMSprop, SGD, Adam
from tensorflow.keras import regularizers
from keras.callbacks import ModelCheckpoint # sirve para dar respuesta del proceso de entrenamiento de la red

# %%
experiment = comet_ml.Experiment(  # Para activar las Graficas de comet
    auto_histogram_weight_logging=True,
    auto_histogram_gradient_logging=True,
    auto_histogram_activation_logging=True,
    log_code=True, # para subir el codigo a comet para no perder el progreso
)
# Out:
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.com/nicglowss/rna-densa-l2/951d78f4ec6c4c4fa78c7c9d7eaafea1
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 2
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/nicglowss/rna-densa-l2/f31ae2aa28a6437996cbfe5ffbcf7bae

# %%
# pre-procesamiento, aqui normalizamos la informacion de los pixeles
# Lo principal con la red es tener la misma normalizacion y tamaño de imagen.
dataset=mnist.load_data()# en el dataset se guardan todas las imagenes del mnist con sus etiquetas
(x_train, y_train), (x_test, y_test) = dataset

# se van a guardar en el forato de binario
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

# =numero de pixeles normalizando el no. de pixeles
x_train /= 255  # x_trainv = x_trainv/255
x_test /= 255

#clasificacion de clases
num_classes=10
y_trainc = keras.utils.to_categorical(y_train, num_classes) #analiza los datos y los acomoda en las distintas clases
y_testc = keras.utils.to_categorical(y_test, num_classes)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
# Parmaetros
parameters = {
    "batch_size": 10,
    "epochs": 30,
    "optimizer": "SGD",
    "loss": "categorical_crossentropy",
}

experiment.log_parameters(parameters) # diccionario subido a comet

# %%
#Arquitetura de la red
model = Sequential()
# aqui empezamos
model.add(Input(shape=(28,28))) #Flaten no tiene la opcion input_shape por lo tanto se tiene que agregar esta capa
                                #28x28 es el tamaño de la imagen
model.add(Flatten()) #Otra forma de aplanar las imagenes, las forma en una linea
model.add(Dense(784, activation='sigmoid', kernel_regularizer=regularizers.L2(0.001)))
                                            # esta es la capa densa de no neuronas de forma vertical (en este caso agarramos el total de pixeles)
                                            # su funcion de activacion es la sigmoide (respuesta de la neurona de 0 a 1)
                                            # Estas dos son las principales

model.add(Dense(10, activation='softmax'))  # son las de salida literal porque estan al final

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 784)               615440
#
#  dense_1 (Dense)             (None, 10)                7850
#
# =================================================================
# Total params: 623290 (2.38 MB)
# Trainable params: 623290 (2.38 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# specify the path where you want to save the model
filepath = "mejor-modelo1.1.hdf5"

# initialize the ModelCheckpoint callback
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# %%
# Inicia el entrenamiento de la red
model.compile(loss=parameters['loss'],optimizer='SGD',metrics=['accuracy'])
historial=model.fit(x_train, y_trainc,
                    batch_size=parameters['batch_size'],
                    epochs=parameters["epochs"],
                    verbose=1,
                    validation_data=(x_test, y_testc),
                    callbacks=[checkpoint])
# Out:
# COMET INFO: Ignoring automatic log_parameter('verbose') because 'keras:verbose' is in COMET_LOGGING_PARAMETERS_IGNORE
# Epoch 1/30
# 5995/6000 [============================>.] - ETA: 0s - loss: 1.5041 - accuracy: 0.8000
# Epoch 1: val_loss improved from inf to 1.08013, saving model to mejor-modelo1.1.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 6000/6000 [==============================] - 54s 9ms/step - loss: 1.5039 - accuracy: 0.8001 - val_loss: 1.0801 - val_accuracy: 0.8904
# Epoch 2/30
# 6000/6000 [==============================] - ETA: 0s - loss: 0.9990 - accuracy: 0.8882
# Epoch 2: val_loss improved from 1.08013 to 0.89129, saving model to mejor-modelo1.1.hdf5
# 6000/6000 [==============================] - 56s 9ms/step - loss: 0.9990 - accuracy: 0.8882 - val_loss: 0.8913 - val_accuracy: 0.9043
# Epoch 3/30
# 5999/6000 [============================>.] - ETA: 0s - loss: 0.8444 - accuracy: 0.8991
# Epoch 3: val_loss improved from 0.89129 to 0.76456, saving model to mejor-modelo1.1.hdf5
# 6000/6000 [==============================] - 52s 9ms/step - loss: 0.8444 - accuracy: 0.8991 - val_loss: 0.7646 - val_accuracy: 0.9099
# Epoch 4/30
# 6000/6000 [==============================] - ETA: 0s - loss: 0.7360 - accuracy: 0.9049
# Epoch 4: val_loss improved from 0.76456 to 0.67664, saving model to mejor-modelo1.1.hdf5
# 6000/6000 [==============================] - 55s 9ms/step - loss: 0.7360 - accuracy: 0.9049 - val_loss: 0.6766 - val_accuracy: 0.9121
# Epoch 5/30
# 5996/6000 [============================>.] - ETA: 0s - loss: 0.6529 - accuracy: 0.9076
# Epoch 5: val_loss improved from 0.67664 to 0.60966, saving model to mejor-modelo1.1.hdf5
# 6000/6000 [==============================] - 50s 8ms/step - loss: 0.6530 - accuracy: 0.9075 - val_loss: 0.6097 - val_accuracy: 0.9074
# Epoch 6/30
# 5995/6000 [============================>.] - ETA: 0s - loss: 0.5882 - accuracy: 0.9094
# Epoch 6: val_loss improved from 0.60966 to 0.55186, saving model to mejor-modelo1.1.hdf5
# 6000/6000 [==============================] - 49s 8ms/step - loss: 0.5881 - accuracy: 0.9095 - val_loss: 0.5519 - val_accuracy: 0.9124
# Epoch 7/30
# 5996/6000 [============================>.] - ETA: 0s - loss: 0.5376 - accuracy: 0.9120
# Epoch 7: val_loss improved from 0.55186 to 0.50126, saving model to mejor-modelo1.1.hdf5
# 6000/6000 [==============================] - 58s 10ms/step - loss: 0.5375 - accuracy: 0.9121 - val_loss: 0.5013 - val_accuracy: 0.9150
# Epoch 8/30
# Epoch 28/30
# 6000/6000 [==============================] - ETA: 0s - loss: 0.3219 - accuracy: 0.9246
# Epoch 28: val_loss improved from 0.31683 to 0.31614, saving model to mejor-modelo1.1.hdf5
# 6000/6000 [==============================] - 52s 9ms/step - loss: 0.3219 - accuracy: 0.9246 - val_loss: 0.3161 - val_accuracy: 0.9278
# Epoch 29/30
# 5997/6000 [============================>.] - ETA: 0s - loss: 0.3189 - accuracy: 0.9256
# Epoch 29: val_loss improved from 0.31614 to 0.31164, saving model to mejor-modelo1.1.hdf5
# 6000/6000 [==============================] - 49s 8ms/step - loss: 0.3189 - accuracy: 0.9256 - val_loss: 0.3116 - val_accuracy: 0.9265
# Epoch 30/30
# 5995/6000 [============================>.] - ETA: 0s - loss: 0.3168 - accuracy: 0.9259
# Epoch 30: val_loss did not improve from 0.31164
# 6000/6000 [==============================] - 60s 10ms/step - loss: 0.3167 - accuracy: 0.9260 - val_loss: 0.3247 - val_accuracy: 0.9199

# %%
experiment.log_model("MNIST1", "mejor-modelo1.1.hdf5")
# Out:
# {'web': 'https://www.comet.com/api/asset/download?assetId=e9da683331744f3e8ca83a1ba6177f8f&experimentKey=f31ae2aa28a6437996cbfe5ffbcf7bae',
#  'api': 'https://www.comet.com/api/rest/v2/experiment/asset/get-asset?assetId=e9da683331744f3e8ca83a1ba6177f8f&experimentKey=f31ae2aa28a6437996cbfe5ffbcf7bae',
#  'assetId': 'e9da683331744f3e8ca83a1ba6177f8f'}

# %%
experiment.end()
# Out:
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.com/nicglowss/rna-densa-l2/f31ae2aa28a6437996cbfe5ffbcf7bae
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     accuracy [30]                  : (0.8000500202178955, 0.9259833097457886)
# COMET INFO:     batch_accuracy [18000]         : (0.09090909361839294, 1.0)
# COMET INFO:     batch_loss [18000]             : (0.09319023787975311, 3.3168625831604004)
# COMET INFO:     epoch_duration [30]            : (44.05729746799989, 63.76835957200001)
# COMET INFO:     loss [30]                      : (0.3167181611061096, 1.503906488418579)
# COMET INFO:     val_accuracy [30]              : (0.8903999924659729, 0.9277999997138977)
# COMET INFO:     val_loss [30]                  : (0.3116435110569, 1.0801326036453247)
# COMET INFO:     validate_batch_accuracy [3000] : (0.8529411554336548, 0.9666666388511658)
# COMET INFO:     validate_batch_loss [3000]     : (0.22984473407268524, 1.189414143562317)
# COMET INFO:   Others:
# COMET INFO:     trainable_params : 623290
# COMET INFO:   Parameters:
# COMET INFO:     Optimizer                   : SGD
# COMET INFO:     SGD_clipnorm                : None
# COMET INFO:     SGD_clipvalue               : None
# COMET INFO:     SGD_ema_momentum            : 0.99
# COMET INFO:     SGD_ema_overwrite_frequency : None
# COMET INFO:     SGD_global_clipnorm         : None
# COMET INFO:     SGD_is_legacy_optimizer     : False
# COMET INFO:     SGD_jit_compile             : False
# COMET INFO:     SGD_learning_rate           : 0.009999999776482582
# COMET INFO:     SGD_momentum                : 0.0
# COMET INFO:     SGD_name                    : SGD
# COMET INFO:     SGD_nesterov                : False
# COMET INFO:     SGD_use_ema                 : False
# COMET INFO:     SGD_weight_decay            : None
# COMET INFO:     batch_size                  : 10
# COMET INFO:     epochs                      : 30
# COMET INFO:     loss                        : categorical_crossentropy
# COMET INFO:     optimizer                   : SGD
# COMET INFO:     steps                       : 6000
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     histogram3d         : 217
# COMET INFO:     installed packages  : 1
# COMET INFO:     model graph         : 1
# COMET INFO:     model-element       : 1 (4.78 MB)
# COMET INFO:     notebook            : 2
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
